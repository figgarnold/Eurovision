# %%
import pandas as pd
import re
import numpy as np
import ast

# %%
df = pd.read_csv("features_partial.csv")

# %% [markdown]
# # Danceability
# Essentia returns an aggregate danceability score and a framewise curve. For the initial project scope, extracting the aggregated number should be sufficient. These values usually range from 0 to 3 (higher values meaning more danceable).

# %%
df["track_danceability"] = df["Danceability"].apply(
    lambda x: round(float(re.search(r"\(([\d\.]+)", x).group(1)), 4)
)
print(df.head())
# Out:
#                                         Danceability         bpm  \
# 0  (1.0577861070632935, array([1.3124456 , 1.2694...  135.828598
# 1  (1.0577861070632935, array([1.3124456 , 1.2694...  135.828598
# 2  (1.1427139043807983, array([1.0092717 , 0.9785...  136.526443
# 3  (1.0489819049835205, array([1.2052338 , 1.1632...  109.182640
# 4  (0.9722141623497009, array([1.0625372 , 1.0406...   90.967430
#
#                                      rhythm_strength       key  \
# 0  [0.63854873 0.63854873 0.6269387  0.522449   0...  0.058114
# 1  [0.63854873 0.63854873 0.6269387  0.522449   0...  0.058114
# 2  [0.7894784  0.7778685  0.80108833 0.7662585  0...  0.083988
# 3  [0.487619   0.46439916 0.45278907 0.476009   0...  0.055757
# 4  [0.5688889  0.5572789  0.5572789  0.5688889  0...  0.051498
#
#                                         scale_vector       track  \
# 0  [31.765575    9.234179   29.007633    1.034228...     track_0
# 1  [31.765575    9.234179   29.007633    1.034228...     track_1
# 2  [ 5.126527    3.5994763  11.1474695   2.748691...    track_10
# 3  [41.443398    2.172339   15.954622    0.265508...   track_100
# 4  [22.47191     7.794944   14.349251    4.002809...  track_1002
#
#                                youtube_url  track_danceability
# 0  https://youtube.com/watch?v=u45UQVGRVPA              1.0578
# 1  https://youtube.com/watch?v=u45UQVGRVPA              1.0578
# 2  https://youtube.com/watch?v=Pv7GJkqtNuc              1.1427
# 3  https://youtube.com/watch?v=lWINVYSsrTU              1.0490
# 4  https://youtube.com/watch?v=SXlIN3mcsH4              0.9722

# %% [markdown]
# # BPM
# The beats per minute (BPM) score is a fairly straight forward Tempo measure. There's little need to transform at this stage of the project.

# %% [markdown]
# # Rythm Strength
# This is currently captured as a per-frame measurement of rythmic strength. To enable swift comparison, I am going to create two variables; one for the mean and one for the variance, i.e. does it chance much.

# %%
df["rhythm_strength"] = df["rhythm_strength"].apply(
    lambda x: np.fromstring(x.strip("[]"), sep=" ")
)

# %%
# calc mean per row
df["mean_rhythm_strength"] = df["rhythm_strength"].apply(
    lambda arr: np.mean(arr)
)

# calc variance per row
df["var_rhythm_strength"] = df["rhythm_strength"].apply(
    lambda arr: np.var(arr)
)

df.head()
# Out:
#                                         Danceability         bpm  \
# 0  (1.4968905448913574, array([1.0434638 , 1.0139...  123.938477
# 1  (1.1244194507598877, array([0.86909485, 0.8541...  123.789642
# 2  (1.5002362728118896, array([0.89553595, 0.8321...  108.004150
# 3  (1.1257785558700562, array([1.1045734 , 1.0890...  123.656113
# 4  (1.1556165218353271, array([0.9028398 , 0.8871...  128.019058
#
#                                      rhythm_strength       key  \
# 0  [0.534059, 0.5340589, 0.54566884, 0.510839, 0....  0.083312
# 1  [0.46439907, 0.4643991, 0.4643991, 0.47600913,...  0.069519
# 2  [0.5688889, 0.5572789, 0.5572789, 0.54566884, ...  0.070080
# 3  [0.49922907, 0.49922895, 0.47600913, 0.4992289...  0.061682
# 4  [0.55727893, 0.54566896, 0.54566884, 0.5572789...  0.067957
#
#                                         scale_vector      track  \
# 0  [ 8.903932    6.5607915  41.18719     7.289768...  track_861
# 1  [18.305223   18.366928    3.475936    2.920608...  track_863
# 2  [37.781227    6.3873806   7.266615    0.310318...  track_864
# 3  [28.751259    6.9234643  13.242699    1.636455...  track_866
# 4  [20.169893    4.681944    9.324378    5.788226...  track_872
#
#                                youtube_url  track_danceability  \
# 0  https://youtube.com/watch?v=jQEcQNtouAg              1.4969
# 1  https://youtube.com/watch?v=qNs-R9NU82I              1.1244
# 2  https://youtube.com/watch?v=UrrRqk7HRlw              1.5002
# 3  https://youtube.com/watch?v=2NSR5rSk0Cs              1.1258
# 4  https://youtube.com/watch?v=tky7vWXSZrs              1.1556
#
#    mean_rhythm_strength  var_rhythm_strength
# 0              0.484415             0.000059
# 1              0.478455             0.002231
# 2              0.555579             0.000024
# 3              0.474866             0.000849
# 4              0.496172             0.002795

# %% [markdown]
# # Key
# It became apparent that I had unfortunately only saved the Confidence in the Key and Scale calculated by Essentia, but not the Key and Scale themeselves. The issue is that the pipeline I have built automatically removes the audio after analysis as audio files are large. Given the significant time it takes to download, I have asked Copilot the following "I no longer have the audio files to run Essentia. Can I use the PCP vector to calculate the Key and Scale?"

# %%
def normalize_profile(p):
    p = np.clip(p, 0, None)
    s = p.sum()
    return p / s if s > 0 else p

def fold_to_12(p):
    if len(p) % 12 != 0:
        raise ValueError("Profile length must be a multiple of 12.")
    n = len(p) // 12
    return p.reshape(12, n).sum(axis=1)

# Krumhansl–Schmuckler templates
major_template = np.array([6.35,2.23,3.48,2.33,4.38,4.09,
                           2.52,5.19,2.39,3.66,2.29,2.88])
minor_template = np.array([6.33,2.68,3.52,5.38,2.60,3.53,
                           2.54,4.75,3.98,2.69,3.34,3.17])
major_template /= major_template.sum()
minor_template /= minor_template.sum()

pitch_names = ["C","C#","D","D#","E","F","F#","G","G#","A","A#","B"]

def best_key(pcp12, template):
    scores = []
    for shift in range(12):
        rotated = np.roll(template, shift)
        num = np.dot(pcp12, rotated)
        den = np.linalg.norm(pcp12) * np.linalg.norm(rotated)
        scores.append(num/den if den > 0 else 0.0)
    best_shift = int(np.argmax(scores))
    return best_shift, scores[best_shift]

def estimate_key_from_profile(profile):
    p = np.array(profile, dtype=float)
    p12 = normalize_profile(fold_to_12(normalize_profile(p)))
    maj_shift, maj_score = best_key(p12, major_template)
    min_shift, min_score = best_key(p12, minor_template)
    if maj_score >= min_score:
        return f"{pitch_names[maj_shift]} major"
    else:
        return f"{pitch_names[min_shift]} minor"

df["key_scale"] = df["scale_vector"].apply(
    lambda x: estimate_key_from_profile(np.fromstring(x.strip("[]"), sep=" "))
)

df.head()
# Out:
#                                         Danceability         bpm  \
# 0  (1.0577861070632935, array([1.3124456 , 1.2694...  135.828598
# 1  (1.0577861070632935, array([1.3124456 , 1.2694...  135.828598
# 2  (1.1427139043807983, array([1.0092717 , 0.9785...  136.526443
# 3  (1.0489819049835205, array([1.2052338 , 1.1632...  109.182640
# 4  (0.9722141623497009, array([1.0625372 , 1.0406...   90.967430
#
#                                      rhythm_strength       key  \
# 0  [0.63854873, 0.63854873, 0.6269387, 0.522449, ...  0.058114
# 1  [0.63854873, 0.63854873, 0.6269387, 0.522449, ...  0.058114
# 2  [0.7894784, 0.7778685, 0.80108833, 0.7662585, ...  0.083988
# 3  [0.487619, 0.46439916, 0.45278907, 0.476009, 0...  0.055757
# 4  [0.5688889, 0.5572789, 0.5572789, 0.5688889, 0...  0.051498
#
#                                         scale_vector       track  \
# 0  [31.765575    9.234179   29.007633    1.034228...     track_0
# 1  [31.765575    9.234179   29.007633    1.034228...     track_1
# 2  [ 5.126527    3.5994763  11.1474695   2.748691...    track_10
# 3  [41.443398    2.172339   15.954622    0.265508...   track_100
# 4  [22.47191     7.794944   14.349251    4.002809...  track_1002
#
#                                youtube_url  track_danceability key_scale
# 0  https://youtube.com/watch?v=u45UQVGRVPA              1.0578   C minor
# 1  https://youtube.com/watch?v=u45UQVGRVPA              1.0578   C minor
# 2  https://youtube.com/watch?v=Pv7GJkqtNuc              1.1427  G# major
# 3  https://youtube.com/watch?v=lWINVYSsrTU              1.0490   C major
# 4  https://youtube.com/watch?v=SXlIN3mcsH4              0.9722   C minor

# %% [markdown]
# # Pitch Class Profile (PCP) (scale_vector)
# Summarizes tonal information across a track (regardless of octave). For example. Dance tracks are likely to have a clear tonal centre.

# %%
df["scale_vector"] = df["scale_vector"].apply(
    lambda x: np.fromstring(x.strip("[]"), sep=" ")
)

# %%
df["var_PCP"]   = df["scale_vector"].apply(np.var)
df["max_PCP"]   = df["scale_vector"].apply(np.max)
df["dominant_pitch"] = df["scale_vector"].apply(lambda arr: np.argmax(arr))

pitch_classes = ["C","C#","D","D#","E","F","F#","G","G#","A","A#","B"]

df["dominant_pitch_class"] = df["dominant_pitch"].apply(
    lambda idx: pitch_classes[idx % 12] )

df.tail(20)
# Out:
#                                           Danceability         bpm  \
# 307  (1.00360906124115, array([1.0515424 , 1.035172...  166.419998
# 308  (1.210000991821289, array([0.9396195 , 0.93717...  133.836166
# 309  (1.0260013341903687, array([1.1282192 , 1.0812...  101.644493
# 310  (1.160965085029602, array([1.0300467 , 1.00730...  126.011253
# 311  (1.3071630001068115, array([0.9774067 , 0.9507...  132.003861
# 312  (1.2390305995941162, array([1.0249194 , 1.0248...  172.265472
# 313  (0.9982732534408569, array([1.0360991 , 1.0149...  100.828697
# 314  (1.087671160697937, array([1.0670943 , 1.01523...  172.265213
# 315  (0.9926857948303223, array([1.2901363 , 1.2610...  114.033974
# 316  (1.1648662090301514, array([1.0372434 , 0.9856...  112.914597
# 317  (1.3589743375778198, array([1.1262982 , 1.0685...   95.777336
# 318  (0.9566870331764221, array([1.0669539, 1.07517...  135.923523
# 319  (1.3157411813735962, array([1.121392  , 1.0931...  129.964722
# 320  (1.4859180450439453, array([0.9560591 , 0.8953...  112.961083
# 321  (1.004401445388794, array([0.94985235, 0.97667...   85.032776
# 322  (1.4689536094665527, array([1.0414721 , 1.0035...  143.917725
# 323  (1.2489079236984253, array([1.087012  , 1.0439...  184.570648
# 324  (1.219077706336975, array([0.92420006, 0.84737...  104.863152
# 325  (1.1370203495025635, array([1.1732394 , 1.1424...  103.799141
# 326  (1.187842845916748, array([0.9449648 , 0.92934...  135.133362
#
#                                        rhythm_strength       key  \
# 307  [0.55727893, 0.5572789, 0.557279, 0.5572789, 0...  0.047485
# 308  [0.44117913, 0.46439904, 0.47600913, 0.4643989...  0.066387
# 309  [0.499229, 0.522449, 0.5340589, 0.54566884, 0....  0.059789
# 310  [0.47600907, 0.47600907, 0.476009, 0.47600913,...  0.072219
# 311  [0.4527891, 0.47600907, 0.47600913, 0.4643991,...  0.062013
# 312  [0.35990933, 0.34829926, 0.34829938, 0.3599093...  0.039581
# 313  [0.3599093, 0.35990924, 0.3599093, 0.3599093, ...  0.059770
# 314  [0.5572789, 0.5688889, 0.557279, 0.5572789, 0....  0.065264
# 315  [0.5688889, 0.5688889, 0.55727875, 0.5688889, ...  0.071031
# 316  [0.60371876, 0.6037189, 0.5921087, 0.58049893,...  0.072397
# 317  [0.54566896, 0.5688889, 0.5688888, 0.5688889, ...  0.051758
# 318  [0.5572789, 0.54566896, 0.54566884, 0.5572791,...  0.049823
# 319  [0.4527891, 0.45278907, 0.44117916, 0.45278907...  0.085708
# 320  [0.41795918, 0.41795915, 0.4179592, 0.4179591,...  0.073094
# 321  [0.7778685, 0.7778685, 0.7894783, 0.78947854, ...  0.073635
# 322  [0.4179592, 0.41795915, 0.40634918, 0.40634918...  0.041351
# 323  [0.34829935, 0.3366893, 0.33668935, 0.34829926...  0.090227
# 324  [0.6849886, 0.6617688, 0.6617687, 0.60371876, ...  0.077209
# 325  [0.59210885, 0.60371876, 0.60371876, 0.5921089...  0.081867
# 326  [0.3947392, 0.3947392, 0.39473927, 0.38312924,...  0.074542
#
#                                           scale_vector      track  \
# 307  [18.538595, 21.335646, 30.659149, 4.5750217, 7...  track_768
# 308  [28.232971, 11.920039, 8.859822, 6.194472, 12....  track_777
# 309  [14.161782, 8.393904, 22.907385, 5.345838, 11....  track_779
# 310  [48.444912, 1.686874, 14.681075, 2.6093833, 2....  track_785
# 311  [10.326933, 8.588479, 33.990658, 18.033213, 2....  track_807
# 312  [47.727272, 4.5199184, 3.2686415, 8.146068, 1....  track_910
# 313  [4.6327415, 5.68891, 4.1286607, 1.4402305, 1.5...  track_919
# 314  [9.90778, 28.32821, 24.946796, 3.9016316, 0.63...  track_924
# 315  [16.750597, 2.4118738, 6.679035, 2.0408163, 3....   track_93
# 316  [23.898306, 4.6731234, 6.0290556, 8.74092, 0.4...  track_930
# 317  [33.580982, 4.779594, 1.4611194, 4.4328876, 2....   track_95
# 318  [46.77686, 2.2195985, 10.956316, 0.0, 2.502951...  track_953
# 319  [9.4815502, 26.973377, 3.2928538, 7.8234468, 6...  track_954
# 320  [9.5455637, 0.0, 24.116375, 6.3957682, 4.13560...  track_969
# 321  [19.140533, 11.219512, 9.361208, 8.73403, 1.62...  track_999
# 322  [21.457388, 4.538578, 16.691881, 1.0337873, 8....  track_809
# 323  [10.850715, 5.5073824, 10.569487, 1.8748535, 1...  track_815
# 324  [27.097254, 5.122494, 6.359812, 13.981688, 5.4...  track_826
# 325  [20.297699, 2.2553, 11.95309, 3.450609, 11.434...  track_831
# 326  [15.097188, 14.965088, 24.419703, 8.75637, 12....  track_838
#
#                                  youtube_url  track_danceability key_scale  \
# 307  https://youtube.com/watch?v=azw4Kh8Rqpw              1.0036  C# major
# 308  https://youtube.com/watch?v=fZ5B6w-Baxs              1.2100   C major
# 309  https://youtube.com/watch?v=g0AQI_Nt1X4              1.0260  A# minor
# 310  https://youtube.com/watch?v=0nusBQ7Lacg              1.1610   C major
# 311  https://youtube.com/watch?v=0c_2T-DZUe0              1.3072  C# major
# 312  https://youtube.com/watch?v=RRQlsvWMWBo              1.2390   C major
# 313  https://youtube.com/watch?v=z7OvpjplJ_8              0.9983   A minor
# 314  https://youtube.com/watch?v=10XR67NQcAc              1.0877   C major
# 315  https://youtube.com/watch?v=gn8GMilGDZw              0.9927   C major
# 316  https://youtube.com/watch?v=asZwDUTEXls              1.1649   E minor
# 317  https://youtube.com/watch?v=AYyhJvRE3mQ              1.3590   C minor
# 318  https://youtube.com/watch?v=Vv8GmwcfR9A              0.9567   C major
# 319  https://youtube.com/watch?v=bGY20O4Z7nM              1.3157   C major
# 320  https://youtube.com/watch?v=ghQZojJWxKI              1.4859  C# minor
# 321  https://youtube.com/watch?v=waYpnAexrUA              1.0044   C major
# 322  https://youtube.com/watch?v=n2NU4H85J4o              1.4690  A# minor
# 323  https://youtube.com/watch?v=9c1aVpRDYUU              1.2489  G# minor
# 324  https://youtube.com/watch?v=4HtYwbnihmo              1.2191   C minor
# 325  https://youtube.com/watch?v=F-JwiYlg5Gc              1.1370   B minor
# 326  https://youtube.com/watch?v=ZutVRMXoiiU              1.1878  C# minor
#
#         var_PCP    max_PCP  dominant_pitch dominant_pitch_class
# 307   59.950183  30.659149               2                    D
# 308   39.979335  28.232971               0                    C
# 309   29.373031  22.907385               2                    D
# 310  101.269850  48.444912               0                    C
# 311   57.076866  33.990658               2                    D
# 312  110.963165  47.727272               0                    C
# 313   27.275074  22.203552              19                    G
# 314   52.818909  28.328210               1                   C#
# 315   12.885366  16.750597               0                    C
# 316   43.964658  23.898306               0                    C
# 317   56.785141  33.580982               0                    C
# 318   88.286180  46.776860               0                    C
# 319   29.809025  26.973377               1                   C#
# 320   39.479544  24.116375               2                    D
# 321   33.705766  20.209059              22                   A#
# 322   38.466794  21.457388               0                    C
# 323   27.052992  22.849777              23                    B
# 324   34.751335  27.097254               0                    C
# 325   26.305400  20.297699               0                    C
# 326   39.894580  24.419703               2                    D

# %%
df.to_csv("audiofeatures.csv", index=False)

# %% [markdown]
# # now join to table on youtube url
