# %%
import pandas as pd
from langdetect import detect, detect_langs
from deep_translator import GoogleTranslator

# %%
df = pd.read_csv("contestants_with_spotify.csv")
df.head
# Out:
# <bound method NDFrame.head of       year to_country_id   to_country                     artist  \
# 0     1956            ch  Switzerland                  Lys Assia
# 1     1956            nl  Netherlands                Jetty Paerl
# 2     1956            be      Belgium                Fud Leclerc
# 3     1956            de      Germany     Walter Andreas Schwarz
# 4     1956            fr       France               Mathé Altéry
# ...    ...           ...          ...                        ...
# 1729  2023            lv       Latvia              Sudden Lights
# 1730  2023            ie      Ireland                 Wild Youth
# 1731  2023            nl  Netherlands  Mia Nicolai & Dion Cooper
# 1732  2023            az   Azerbaijan                TuralTuranX
# 1733  2023            mt        Malta                 The Busker
#
#                                  song  place_contest  sf_num  running_final  \
# 0                             Refrain            2.0     NaN            2.0
# 1               De Vogels Van Holland            2.0     NaN            1.0
# 2     Messieurs Les Noyés De La Seine            2.0     NaN            3.0
# 3       Im Wartesaal Zum Großen Glück            2.0     NaN            4.0
# 4                      Le Temps Perdu            2.0     NaN            5.0
# ...                               ...            ...     ...            ...
# 1729                             Aijā            NaN     1.0            NaN
# 1730                       We Are One            NaN     1.0            NaN
# 1731                 Burning Daylight            NaN     1.0            NaN
# 1732                     Tell Me More            NaN     1.0            NaN
# 1733            Dance (Our Own Party)            NaN     1.0            NaN
#
#       running_sf  place_final  ...  \
# 0            NaN          2.0  ...
# 1            NaN          2.0  ...
# 2            NaN          2.0  ...
# 3            NaN          2.0  ...
# 4            NaN          2.0  ...
# ...          ...          ...  ...
# 1729         4.0          NaN  ...
# 1730         6.0          NaN  ...
# 1731        14.0          NaN  ...
# 1732        12.0          NaN  ...
# 1733         2.0          NaN  ...
#
#                                               composers  \
# 0                                      Georg Benz Stahl
# 1                                           Cor Lemaire
# 2                                Jacques Say;Jean Miret
# 3                                Walter Andreas Schwarz
# 4                                           André Lodge
# ...                                                 ...
# 1729  Andrejs Reinis Zitmanis;Kārlis Matīss Zitmanis...
# 1730      Conor O'Donohoe;Edward Porter;Jörgen Elofsson
# 1731  Dion Cooper;Duncan Laurence;Jordan Garfield;Lo...
# 1732  Nihad Aliyev;Tunar Tağiyev;Tural Bağmanov;Tura...
# 1733  David Meilak;Jean Paul Borg;Matthew James Borg...
#
#                           lyricists  \
# 0                               NaN
# 1               Annie M. G. Schmidt
# 2                     Robert Montal
# 3                               NaN
# 4                   Rachèle Thoreau
# ...                             ...
# 1729        Andrejs Reinis Zitmanis
# 1730                            NaN
# 1731                            NaN
# 1732  Tural Bağmanov;Turan Bağmanov
# 1733                   David Meilak
#
#                                                  lyrics  \
# 0     (Refrain d'amour...)\n\nRefrain, couleur du ci...
# 1     De vogels van Holland zijn zo muzikaal\nZe ler...
# 2     Messieurs les noyés de la Seine\nOuvrez-moi le...
# 3     Es gibt einen Hafen, da fährt kaum ein Schiff\...
# 4     Chante, carillon\nLe chant du temps perdu\nCha...
# ...                                                 ...
# 1729  Aijā\n\nYou said some words didn't hear you fa...
# 1730  We Are One\n\nWe take our first breath\nAnd th...
# 1731  Burning Daylight\n\nI don't find any joy anymo...
# 1732  Tell Me More\n\nYour call has been forwarded t...
# 1733  Dance (Our Own Party)\n\nWait now, can you spe...
#
#                                   youtube_url        spotify_track_id  \
# 0     https://youtube.com/watch?v=IyqIPvOkiRk  0OtKMBmhEuQ4hGPbMmtErz
# 1     https://youtube.com/watch?v=u45UQVGRVPA  0TwQ2TgfJxZbyeQvCzeMKY
# 2     https://youtube.com/watch?v=U9O3sqlyra0                     NaN
# 3     https://youtube.com/watch?v=BDNARIDnmTc  6GEjmkRXCf0WCWptS9sRGb
# 4     https://youtube.com/watch?v=dm1L0XyikKI                     NaN
# ...                                       ...                     ...
# 1729  https://youtube.com/watch?v=xAjVA3qwqGk  2XhLiOVoMTWR0LNkvVEYA5
# 1730  https://youtube.com/watch?v=ak5Fevs424Y  2QYVjerrhcF6LuDC3zWbWx
# 1731  https://youtube.com/watch?v=UOf-oKDlO6A  5pjp1jN7hitQTuSlT2jOep
# 1732  https://youtube.com/watch?v=5dvsr-L3HgY  2pXSRhFrsoG57v4tZ36ogu
# 1733  https://youtube.com/watch?v=Apqwl0ayL6A  3natKRDYwMSPsLO9nX8y02
#
#                  spotify_track_name  \
# 0                           Refrain
# 1             De Vogels Van Holland
# 2                               NaN
# 3     Im Wartesaal zum großen Glück
# 4                               NaN
# ...                             ...
# 1729                           Aijā
# 1730                     We Are One
# 1731               Burning Daylight
# 1732                   Tell Me More
# 1733          Dance (Our Own Party)
#
#                                spotify_album_name spotify_album_release_date  \
# 0                                 Schwarze Perlen                 17/12/1953
# 1                       Europop (Legends Edition)                 19/03/2019
# 2                                             NaN                        NaN
# 3     Germany 12 Points 2005 Countdown Grand Prix                 04/03/2005
# 4                                             NaN                        NaN
# ...                                           ...                        ...
# 1729                                         Aijā                 27/01/2023
# 1730                                   We Are One                 27/01/2023
# 1731                             Burning Daylight                 01/03/2023
# 1732                                 Tell Me More                 14/03/2023
# 1733                        Dance (Our Own Party)                 03/03/2023
#
#      spotify_track_popularity  \
# 0                        11.0
# 1                         0.0
# 2                         NaN
# 3                         4.0
# 4                         NaN
# ...                       ...
# 1729                     38.0
# 1730                     32.0
# 1731                     39.0
# 1732                     29.0
# 1733                     35.0
#
#                                             spotify_url
# 0     https://open.spotify.com/track/0OtKMBmhEuQ4hGP...
# 1     https://open.spotify.com/track/0TwQ2TgfJxZbyeQ...
# 2                                                   NaN
# 3     https://open.spotify.com/track/6GEjmkRXCf0WCWp...
# 4                                                   NaN
# ...                                                 ...
# 1729  https://open.spotify.com/track/2XhLiOVoMTWR0LN...
# 1730  https://open.spotify.com/track/2QYVjerrhcF6LuD...
# 1731  https://open.spotify.com/track/5pjp1jN7hitQTuS...
# 1732  https://open.spotify.com/track/2pXSRhFrsoG57v4...
# 1733  https://open.spotify.com/track/3natKRDYwMSPsLO...
#
# [1734 rows x 27 columns]>

# %%
summary = (
    df.groupby("year")
      .agg(
          max_running_final=("running_final", "max"),
          count_entries=("running_final", "count")
      )
      .reset_index()
)
summary["max_not_equal_count"] = summary["max_running_final"] != summary["count_entries"]

print(summary)
# Out:
#     year  max_running_final  count_entries  max_not_equal_count
# 0   1956               14.0             12                 True
# 1   1957               10.0             10                False
# 2   1958               10.0             10                False
# 3   1959               11.0             11                False
# 4   1960               13.0             13                False
# ..   ...                ...            ...                  ...
# 63  2019               26.0             26                False
# 64  2020               23.0              1                 True
# 65  2021               26.0             26                False
# 66  2022               25.0             25                False
# 67  2023               26.0             26                False
#
# [68 rows x 4 columns]

# %%
# Filter rows where max_not_equal_count is True
filtered = summary[summary["max_not_equal_count"]]

print(filtered)
# Out:
#     year  max_running_final  count_entries  max_not_equal_count
# 0   1956               14.0             12                 True
# 64  2020               23.0              1                 True

# %%
def safe_detect(text):
    try:
        if pd.isna(text):   # skip NaN
            return None
        return detect(str(text))  # force to string
    except Exception:
        return None  # fallback if detection fails

df["language"] = df["lyrics"].apply(safe_detect)

df.head(10)
# Out:
#    year to_country_id   to_country                  artist  \
# 0  1956            ch  Switzerland               Lys Assia
# 1  1956            nl  Netherlands             Jetty Paerl
# 2  1956            be      Belgium             Fud Leclerc
# 3  1956            de      Germany  Walter Andreas Schwarz
# 4  1956            fr       France            Mathé Altéry
# 5  1956            lu   Luxembourg          Michèle Arnaud
# 6  1956            it        Italy         Franca Raimondi
# 7  1956            nl  Netherlands           Corry Brokken
# 8  1956            be      Belgium               Mony Marc
# 9  1956            de      Germany            Freddy Quinn
#
#                               song  place_contest  sf_num  running_final  \
# 0                          Refrain            2.0     NaN            2.0
# 1            De Vogels Van Holland            2.0     NaN            1.0
# 2  Messieurs Les Noyés De La Seine            2.0     NaN            3.0
# 3    Im Wartesaal Zum Großen Glück            2.0     NaN            4.0
# 4                   Le Temps Perdu            2.0     NaN            5.0
# 5                     Ne Crois Pas            2.0     NaN           13.0
# 6               Aprite Le Finestre            2.0     NaN            7.0
# 7                 Voorgoed Voorbij            2.0     NaN            8.0
# 8      Le Plus Beau Jour De Ma Vie            2.0     NaN           10.0
# 9           So Geht Das Jede Nacht            2.0     NaN           11.0
#
#    running_sf  place_final  ...            lyricists  \
# 0         NaN          2.0  ...                  NaN
# 1         NaN          2.0  ...  Annie M. G. Schmidt
# 2         NaN          2.0  ...        Robert Montal
# 3         NaN          2.0  ...                  NaN
# 4         NaN          2.0  ...      Rachèle Thoreau
# 5         NaN          2.0  ...                  NaN
# 6         NaN          2.0  ...               Pinchi
# 7         NaN          2.0  ...                  NaN
# 8         NaN          2.0  ...            David Bee
# 9         NaN          2.0  ...         Peter Mösser
#
#                                               lyrics  \
# 0  (Refrain d'amour...)\n\nRefrain, couleur du ci...
# 1  De vogels van Holland zijn zo muzikaal\nZe ler...
# 2  Messieurs les noyés de la Seine\nOuvrez-moi le...
# 3  Es gibt einen Hafen, da fährt kaum ein Schiff\...
# 4  Chante, carillon\nLe chant du temps perdu\nCha...
# 5  Si on te dit qu't'a une belle gueule\nY a pas ...
# 6  La prima rosa rossa è già sbocciata\nE nascon ...
# 7  Voorgoed voorbij\nNu zijn we nooit meer samen\...
# 8  Les cloches sonnent\nTout carillonne\nLe plus ...
# 9  Am Sonntag mit Jimmy, am Montag mit Jack\nAm D...
#
#                                youtube_url        spotify_track_id  \
# 0  https://youtube.com/watch?v=IyqIPvOkiRk  0OtKMBmhEuQ4hGPbMmtErz
# 1  https://youtube.com/watch?v=u45UQVGRVPA  0TwQ2TgfJxZbyeQvCzeMKY
# 2  https://youtube.com/watch?v=U9O3sqlyra0                     NaN
# 3  https://youtube.com/watch?v=BDNARIDnmTc  6GEjmkRXCf0WCWptS9sRGb
# 4  https://youtube.com/watch?v=dm1L0XyikKI                     NaN
# 5  https://youtube.com/watch?v=Pv7GJkqtNuc  6zbFKX74gD44REVhScTvBP
# 6  https://youtube.com/watch?v=HHA1mC2RkKc  2qlN0HtvDVR2c3f1TGT0bb
# 7  https://youtube.com/watch?v=6OjNzLaifFM  6LQLzhnZQqyPAp2H6Cszuz
# 8  https://youtube.com/watch?v=dL139DezFwo                     NaN
# 9  https://youtube.com/watch?v=DJFGwPVKfyk  3m57DgqNNc2MRfKr38hWPb
#
#                 spotify_track_name  \
# 0                          Refrain
# 1            De Vogels Van Holland
# 2                              NaN
# 3    Im Wartesaal zum großen Glück
# 4                              NaN
# 5                     Ne Crois Pas
# 6  Aprite le finestre (remastered)
# 7                 Voorgoed Voorbij
# 8                              NaN
# 9           So Geht Das Jede Nacht
#
#                                   spotify_album_name  \
# 0                                    Schwarze Perlen
# 1                          Europop (Legends Edition)
# 2                                                NaN
# 3        Germany 12 Points 2005 Countdown Grand Prix
# 4                                                NaN
# 5  Vintage French Song No. 142 - EP: Les Amours O...
# 6  El Festival De San Remo - Los Años De Oro (195...
# 7                                       Net Als Toen
# 8                                                NaN
# 9                             Schlager Hits Der 50er
#
#    spotify_album_release_date spotify_track_popularity  \
# 0                  17/12/1953                     11.0
# 1                  19/03/2019                      0.0
# 2                         NaN                      NaN
# 3                  04/03/2005                      4.0
# 4                         NaN                      NaN
# 5                  17/08/1956                      0.0
# 6                  01/01/2006                     16.0
# 7                  20/09/2001                      0.0
# 8                         NaN                      NaN
# 9                  19/02/2010                      1.0
#
#                                          spotify_url language
# 0  https://open.spotify.com/track/0OtKMBmhEuQ4hGP...       fr
# 1  https://open.spotify.com/track/0TwQ2TgfJxZbyeQ...       nl
# 2                                                NaN       fr
# 3  https://open.spotify.com/track/6GEjmkRXCf0WCWp...       de
# 4                                                NaN       fr
# 5  https://open.spotify.com/track/6zbFKX74gD44REV...       fr
# 6  https://open.spotify.com/track/2qlN0HtvDVR2c3f...       it
# 7  https://open.spotify.com/track/6LQLzhnZQqyPAp2...       nl
# 8                                                NaN       fr
# 9  https://open.spotify.com/track/3m57DgqNNc2MRfK...       de
#
# [10 rows x 28 columns]

# %%
#print(df.language.unique())
langsummary = (
    df.groupby("language")
      .agg(
          count_entries=("song", "count")
      )
    .reset_index()
    .sort_values(by="count_entries", ascending=False)
)
print(langsummary)
# Out:
#    language  count_entries
# 5        en            776
# 9        fr            173
# 4        de             91
# 10       hr             86
# 13       it             71
# 6        es             63
# 16       nl             56
# 19       pt             51
# 23       sl             45
# 17       no             45
# 8        fi             39
# 26       sv             37
# 3        da             29
# 29       tr             28
# 7        et             23
# 11       hu             13
# 25       sq             13
# 28       tl             12
# 18       pl             10
# 20       ro             10
# 12       id             10
# 0        af              9
# 22       sk              9
# 1        ca              4
# 24       so              4
# 14       lt              4
# 27       sw              4
# 2        cs              2
# 21       ru              1
# 15       lv              1

# %%
df["lyrics_en"] = df["lyrics"]

mask = (df["language"].notna()) & (df["language"] != "en")

def safe_translate(text):
    if pd.isna(text):
        return None
    try:
        return GoogleTranslator(source="auto", target="en").translate(str(text))
    except Exception as e:
        return f"[Translation error: {e}]"

df.loc[mask, "lyrics_en"] = df.loc[mask, "lyrics"].apply(safe_translate)

print(df.head())
# Out:
#    year to_country_id   to_country                  artist  \
# 0  1956            ch  Switzerland               Lys Assia
# 1  1956            nl  Netherlands             Jetty Paerl
# 2  1956            be      Belgium             Fud Leclerc
# 3  1956            de      Germany  Walter Andreas Schwarz
# 4  1956            fr       France            Mathé Altéry
#
#                               song  place_contest  sf_num  running_final  \
# 0                          Refrain            2.0     NaN            2.0
# 1            De Vogels Van Holland            2.0     NaN            1.0
# 2  Messieurs Les Noyés De La Seine            2.0     NaN            3.0
# 3    Im Wartesaal Zum Großen Glück            2.0     NaN            4.0
# 4                   Le Temps Perdu            2.0     NaN            5.0
#
#    running_sf  place_final  ...  \
# 0         NaN          2.0  ...
# 1         NaN          2.0  ...
# 2         NaN          2.0  ...
# 3         NaN          2.0  ...
# 4         NaN          2.0  ...
#
#                                               lyrics  \
# 0  (Refrain d'amour...)\n\nRefrain, couleur du ci...
# 1  De vogels van Holland zijn zo muzikaal\nZe ler...
# 2  Messieurs les noyés de la Seine\nOuvrez-moi le...
# 3  Es gibt einen Hafen, da fährt kaum ein Schiff\...
# 4  Chante, carillon\nLe chant du temps perdu\nCha...
#
#                                youtube_url        spotify_track_id  \
# 0  https://youtube.com/watch?v=IyqIPvOkiRk  0OtKMBmhEuQ4hGPbMmtErz
# 1  https://youtube.com/watch?v=u45UQVGRVPA  0TwQ2TgfJxZbyeQvCzeMKY
# 2  https://youtube.com/watch?v=U9O3sqlyra0                     NaN
# 3  https://youtube.com/watch?v=BDNARIDnmTc  6GEjmkRXCf0WCWptS9sRGb
# 4  https://youtube.com/watch?v=dm1L0XyikKI                     NaN
#
#               spotify_track_name                           spotify_album_name  \
# 0                        Refrain                              Schwarze Perlen
# 1          De Vogels Van Holland                    Europop (Legends Edition)
# 2                            NaN                                          NaN
# 3  Im Wartesaal zum großen Glück  Germany 12 Points 2005 Countdown Grand Prix
# 4                            NaN                                          NaN
#
#    spotify_album_release_date  spotify_track_popularity  \
# 0                  17/12/1953                      11.0
# 1                  19/03/2019                       0.0
# 2                         NaN                       NaN
# 3                  04/03/2005                       4.0
# 4                         NaN                       NaN
#
#                                          spotify_url language  \
# 0  https://open.spotify.com/track/0OtKMBmhEuQ4hGP...       fr
# 1  https://open.spotify.com/track/0TwQ2TgfJxZbyeQ...       nl
# 2                                                NaN       fr
# 3  https://open.spotify.com/track/6GEjmkRXCf0WCWp...       de
# 4                                                NaN       fr
#
#                                            lyrics_en
# 0  (Chorus of love...)\n\nChorus, color of the sk...
# 1  The birds of Holland are so musical\nThey lear...
# 2  Gentlemen, the drowned men of the Seine\nOpen ...
# 3  There is a harbor where hardly any ships sail\...
# 4  Sing, chime\nThe song of lost time\nSing your ...
#
# [5 rows x 29 columns]

# %%
df.to_csv("translatedlyrics.csv", index=False)
